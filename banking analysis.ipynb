# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv("Banking.csv")

# %%
df.head(5)
# Out:
#   Client ID             Name  Age  Location ID Joined Bank   Banking Contact  \
# 0  IND81288    Raymond Mills   24        34324  06-05-2019    Anthony Torres
# 1  IND65833    Julia Spencer   23        42205  10-12-2001  Jonathan Hawkins
# 2  IND47499   Stephen Murray   27         7314  25-01-2010     Anthony Berry
# 3  IND72498   Virginia Garza   40        34594  28-03-2019        Steve Diaz
# 4  IND60181  Melissa Sanders   46        41269  20-07-2012        Shawn Long
#
#   Nationality            Occupation Fee Structure Loyalty Classification  ...  \
# 0    American  Safety Technician IV          High                   Jade  ...
# 1     African   Software Consultant          High                   Jade  ...
# 2    European    Help Desk Operator          High                   Gold  ...
# 3    American          Geologist II           Mid                 Silver  ...
# 4    American   Assistant Professor           Mid               Platinum  ...
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Client ID                 3000 non-null   object
#  1   Name                      3000 non-null   object
#  2   Age                       3000 non-null   int64
#  3   Location ID               3000 non-null   int64
#  4   Joined Bank               3000 non-null   object
#  5   Banking Contact           3000 non-null   object
#  6   Nationality               3000 non-null   object
#  7   Occupation                3000 non-null   object
#  8   Fee Structure             3000 non-null   object
#  9   Loyalty Classification    3000 non-null   object
#  10  Estimated Income          3000 non-null   float64
#  11  Superannuation Savings    3000 non-null   float64
#  12  Amount of Credit Cards    3000 non-null   int64
# ...

# %%
df.describe()
# Out:
#                Age   Location ID  Estimated Income  Superannuation Savings  \
# count  3000.000000   3000.000000       3000.000000             3000.000000
# mean     51.039667  21563.323000     171305.034263            25531.599673
# std      19.854760  12462.273017     111935.808209            16259.950770
# min      17.000000     12.000000      15919.480000             1482.030000
# 25%      34.000000  10803.500000      82906.595000            12513.775000
# 50%      51.000000  21129.500000     142313.480000            22357.355000
# 75%      69.000000  32054.500000     242290.305000            35464.740000
# max      85.000000  43369.000000     522330.260000            75963.900000
#
#        Amount of Credit Cards  Credit Card Balance    Bank Loans  \
# count             3000.000000          3000.000000  3.000000e+03
# mean                 1.463667          3176.206943  5.913862e+05
# std                  0.676387          2497.094709  4.575570e+05
# ...

# %%
bins=[0,100000,300000,float('inf')]
labels=['Low','Med','High']

df['Income Band']=pd.cut(df['Estimated Income'],bins=bins,labels=labels,right='False')

# %%
df['Income Band'].value_counts()
# Out:
# Income Band
# Med     1517
# Low     1027
# High     456
# Name: count, dtype: int64

# %%
df['Income Band'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Income Band'>

# %%
df.columns
# Out:
# Index(['Client ID', 'Name', 'Age', 'Location ID', 'Joined Bank',
#        'Banking Contact', 'Nationality', 'Occupation', 'Fee Structure',
#        'Loyalty Classification', 'Estimated Income', 'Superannuation Savings',
#        'Amount of Credit Cards', 'Credit Card Balance', 'Bank Loans',
#        'Bank Deposits', 'Checking Accounts', 'Saving Accounts',
#        'Foreign Currency Account', 'Business Lending', 'Properties Owned',
#        'Risk Weighting', 'BRId', 'GenderId', 'IAId', 'Income Band'],
#       dtype='object')

# %%
categorcal_col = df[['BRId', 'GenderId','Amount of Credit Cards','Nationality', 'Occupation', 'Properties Owned','Risk Weighting','IAId','Income Band']]

for col in categorcal_col:
    print(f"value counts for '{col}':")
    display(df[col].value_counts())
# Out:
# value counts for 'BRId':
# BRId
# 3    1352
# 1     660
# 2     495
# 4     493
# Name: count, dtype: int64
# value counts for 'GenderId':
# GenderId
# 2    1512
# 1    1488
# Name: count, dtype: int64
# value counts for 'Amount of Credit Cards':
# Amount of Credit Cards
# 1    1922
# 2     765
# 3     313
# Name: count, dtype: int64
# value counts for 'Nationality':
# Nationality
# European      1309
# Asian          754
# American       507
# Australian     254
# African        176
# Name: count, dtype: int64
# value counts for 'Occupation':
# Occupation
# Associate Professor             28
# Structural Analysis Engineer    28
# Recruiter                       25
# Account Coordinator             24
# Human Resources Manager         24
#                                 ..
# Office Assistant IV              8
# Automation Specialist I          7
# Computer Systems Analyst I       6
# Developer III                    5
# Senior Sales Associate           4
# ...

# %%
for i, predictor in enumerate(df[['BRId', 'GenderId','Amount of Credit Cards','Nationality', 'Occupation', 'Properties Owned','Risk Weighting','IAId','Income Band']]):
    plt.figure(i)
    sns.countplot(data=df,x=predictor,hue='GenderId')

# %%
df.shape
# Out:
# (3000, 26)

# %%
print(df.isna().sum())
# Out:
# Client ID                   0
# Name                        0
# Age                         0
# Location ID                 0
# Joined Bank                 0
# Banking Contact             0
# Nationality                 0
# Occupation                  0
# Fee Structure               0
# Loyalty Classification      0
# Estimated Income            0
# Superannuation Savings      0
# Amount of Credit Cards      0
# Credit Card Balance         0
# Bank Loans                  0
# Bank Deposits               0
# Checking Accounts           0
# Saving Accounts             0
# Foreign Currency Account    0
# Business Lending            0
# Properties Owned            0
# Risk Weighting              0
# BRId                        0
# GenderId                    0
# IAId                        0
# Income Band                 0
# dtype: int64

# %%
df['Joined Bank'] = pd.to_datetime(df['Joined Bank'], format='%d-%m-%Y')

# %%
categorical_cols = ['Client ID', 'GenderId', 'Nationality', 'Occupation', 'Properties Owned', 'Risk Weighting', 'BRId', 'IAId']
for col in categorical_cols:
    df[col] = df[col].astype('category')

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Age'], bins=20, kde=True)
plt.title('Age Distribution')
plt.show()

# %%
plt.figure(figsize=(15, 6))
sns.countplot(data=df, x='Nationality', hue='GenderId')
plt.title('Nationality Distribution by Gender')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 30))
sns.countplot(data=df, y='Occupation', order=df['Occupation'].value_counts().index)
plt.title('Occupation Distribution')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Bank Deposits'], bins=30, kde=True)
plt.title('Bank Deposits Distribution')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='Bank Deposits', y='Business Lending', hue='GenderId')
plt.title('Business Lending vs. Bank Deposits')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=df, x='Properties Owned', y='Bank Deposits', hue='Risk Weighting')
plt.title('Bank Deposits by Properties Owned and Risk Weighting')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='Loyalty Classification', order=df['Loyalty Classification'].value_counts().index)
plt.title('Loyalty Classification Distribution')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='Risk Weighting', hue='GenderId')
plt.title('Risk Weighting by Gender')
plt.show()

# %%
# Top 5 most common occupations
print(df['Occupation'].value_counts().head(5))

# Average bank deposit by occupation
print(df.groupby('Occupation')['Bank Deposits'].mean().sort_values(ascending=False).head(10))

# Top 10 customers by bank deposits
print(df[['Client ID', 'Bank Deposits']].sort_values(by='Bank Deposits', ascending=False).head(10))
# Out:
# Occupation
# Associate Professor             28
# Structural Analysis Engineer    28
# Recruiter                       25
# Account Coordinator             24
# Human Resources Manager         24
# Name: count, dtype: int64
# Occupation
# Software Engineer IV            1.197599e+06
# Safety Technician II            1.171378e+06
# Web Designer III                1.110817e+06
# Social Worker                   1.109109e+06
# Office Assistant III            1.019111e+06
# Research Assistant I            9.825878e+05
# General Manager                 9.822976e+05
# Human Resources Assistant II    9.667233e+05
# Food Chemist                    9.620558e+05
# Software Test Engineer I        9.553175e+05
# Name: Bank Deposits, dtype: float64
#      Client ID  Bank Deposits
# 640   IND68515     3890598.08
# 2307  IND81510     3863355.50
# 1132  IND70565     3808500.26
# 1819  IND91720     3784994.65
# 1643  IND47511     3760505.45
# 2109  IND53236     3667387.28
# ...
